# %% [markdown]
# **SUBMISSION RULES (FOLLOW STRICTLY)**
#
# * One `.py` file OR one Jupyter Notebook
# * Each question clearly separated
# * Use `print(type())` where required
# * Do NOT skip questions

# %% [markdown]
# ### ASSIGNMENT — PYTHON TYPE CONVERSION

# %% [markdown]
# *Question 1*<br>
# Create a variable:
# ```python
# x = "10"
# ```
# Convert it to an integer and print:
# * the value
# * the type

# %%
x = "10"

x_int = int(x)

print(x_int)
print(type(x_int))
# Out:
# 10
# <class 'int'>

# %% [markdown]
# *Question 2*<br>
# Create a variable:
# ```python
# y = "10.5"
# ```
# Convert it to a float and print:
# * the value
# * the type

# %%
y = "10.5"

y_float = float(y)

print(y_float)
print(type(y_float))

# %% [markdown]
# *Question 3*<br>
# Convert the integer `25` into a string and print:
# ```python
# My age is 25
# ```

# %%
print("My age is "+str(25))
# Out:
# My age is 25

# %% [markdown]
# *Question 4*<br>
# Convert the following to boolean and print the result:
# * `0`
# * `1`
# * `""`
# * `"Python"`

# %%
print(bool(0))
print(bool(1))
print(bool(""))
print(bool('Python'))
# Out:
# False
# True
# False
# True

# %% [markdown]
# *Question 5*<br>
# Ask the user for **two numbers** and:
# * convert them to integers
# * print their sum

# %%
a = int(input("Enter the first Number"))
b = int(input("Enter the second Number"))


print(f"Sum of {a} and {b} is: ", a+b)
# Out:
# Sum of 15 and 13 is:  28

# %% [markdown]
# *Question 6*<br>
# Ask the user for a number and:
# * convert it to float
# * multiply it by `2.5`
# * print the result

# %%
x = 12.6

x *=2.5

print(x)
# Out:
# 31.5

# %% [markdown]
# *Question 7*<br>
# Ask the user for their age and print:
# ```python
# After 5 years, your age will be ___
# ```

# %%
a = int(input("Enter your age"))


print(f"After 5 years, your age will be ", a+5)
# Out:
# After 5 years, your age will be  17

# %% [markdown]
# *Question 8*<br>
# Predict the output **before running**:
#
# ```python
# print(int("5") + 5)
# print(str(5) + "5")
# print(bool("0"))
# print(bool(0))
# ```
#
# Then run and verify.

# %%
print(int("5") + 5)
print(str(5) + "5")
print(bool("0"))
print(bool(0))
# Out:
# 10
# 55
# True
# False

# %% [markdown]
# *Question 9*<br>
# Run this code and observe the error:
# ```python
# int("hello")
# ```
# Write down:
# * What error you got
# * Why it happened

# %%
int("hello")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 int("Hello")
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %% [markdown]
# 1. We will get invalid literal for int() error.
#
# 2. It happened as we are changing an string which has alpabets and hence cannot be converted to number

# %% [markdown]
# *Question 10*<br>
# Write a program that:
# * takes input from user
# * safely converts it to integer
# * prints `"Invalid number"` if conversion fails
# <br>
# (Hint: use `try / except`)

# %% [markdown]
# *Question 11*<br>
# Write a program that:
# * asks for item price (float)
# * asks for quantity (int)
# * calculates total cost
# * prints output like:
#
# ```python
# Total cost is 250.0
# ```

# %%
price = float(input("Enter the price of Item: "))
qty = int(input("Enter Quantity: "))
print("Total cost is ",price*qty)
# Out:
# Total cost is  62.5

# %% [markdown]
# ### PRACTICE PROBLEMS — PYTHON OPERATORS

# %% [markdown]
# *Problem 1*<br>
# Create two variables:<br>
# ```python
# a = 15
# b = 4
# ```
# Print:
# * sum
# * difference
# * product
# * division
# * floor division
# * remainder

# %%
a = 15
b = 4
print("Addition:", a + b)
print("Substraction:",a-b)
print("Product:", a * b)
print("Division:",a/b)
print("Floor Division:", a// b)
print("Remainder:",a%b)
# Out:
# Addition: 19
# Substraction: 11
# Product: 60
# Division: 3.75
# Floor Division: 3
# Remainder: 3

# %% [markdown]
# *Problem 2*<br>
# Ask the user for **two numbers** and print:
# * their sum
# * their product

# %%
a = int(input("Enter the first Number"))
b = int(input("Enter the second Number"))


print(f"Sum of {a} and {b} is: ", a+b)
print(f"Product of {a} and {b} is: ", a*b)
# Out:
# Sum of 15 and 4 is:  19
# Product of 15 and 4 is:  60

# %% [markdown]
# *Problem 3*<br>
# Write a program that:
# * takes a number from user
# * prints its square and cube

# %%
a = int(input("Enter your number"))

print(f"Square of {a} is:", a**2)
print(f"Cube of {a} is:", a**3)
# Out:
# Square of 2 is: 4
# Cube of 2 is: 8

# %% [markdown]
# *Problem 4*<br>
# Given:
# ```python
# x = 7
# y = 3
# ```
# Print the result of:
# ```python
# (x + y) * (x - y)
# ```

# %%
x = 7
y = 3

print((x+y)*(x-y))
# Out:
# 40

# %% [markdown]
# *Problem 5*<br>
# Take two numbers from user and print:
# * whether the first is greater than second
# * whether both are equal

# %%
a = int(input("Enter your first number"))
b = int(input("Enter your second number"))

print(f"{a} is greater than {b}:", a>b)
print(f"{a} is equal to {b}:", a==b)
# Out:
# 15 is greater than 9: True
# 15 is equal to 9: False

# %% [markdown]
# *Problem 6*<br>
# Write a program that checks if a number is:
# * greater than 10
# * less than or equal to 50
# Print the results.

# %%
a = int(input("Enter your number"))

print(f"{a} is greater than 10:", a>10)
print(f"{a} is less than or equal to 50:", a<=50)
# Out:
# 1 is greater than 10: False
# 1 is less than or equal to 50: True

# %%
# *Problem 7*

# Predict the output, then run:

print(10 > 5)
print(10 < 5)
print(10 == "10")
print(10 != 10)

# %% [markdown]
# *Problem 8*<br>
# Given:
# ```python
# age = int(input("Enter age: "))
# ```
# Print:
# * True if age is between 18 and 60
# * False otherwise<br>
# (Use `and`)

# %%
age = int(input("Enter age: "))
print(age>=18 and age<=60)
# Out:
# True

# %% [markdown]
# *Problem 9*<br>
# Given:
# ```python
# username = input("Username: ")
# password = input("Password: ")
# ```
# Print `True` only if:
#
# * username is `"admin"` **and**
# * password is `"1234"`

# %%
username = input("Username: ")
password = input("Password: ")


print(username =="admin" and password =="1234")
# Out:
# True

# %%
# *Problem 10*
# Evaluate and print the result:


print(True and False or True)
# Out:
# True

# %% [markdown]
# *Problem 11*
#
# Given:
#
# ```python
# x = 20
# ```
#
# Use assignment operators to:
#
# * add 10
# * subtract 5
# * multiply by 2
# * divide by 5
#
# Print `x` after each step.

# %% [markdown]
# *Problem 12*
#
# Rewrite this using assignment operators:
#
# ```python
# x = x + 3
# y = y * 2
# ```

# %%
x = int(input("Enter your first number"))
y = int(input("Enter your second number"))

x += 3
y *= 2

print(x)
print(y)
# Out:
# 6
# 4

# %% [markdown]
# *Problem 13*
#
# Take a number from user and check:
#
# * if it is divisible by **both 3 and 5**
#
# (Hint: `%` and `and`)

# %%
num = int(input("Enter your number:"))

print(num%3==0 and num%5==0)

# %% [markdown]
# *Problem 14*<br>
# Predict output **before running**:
# ```python
# x = 5
# y = 10
# z = 15
# print(x < y and y < z)
# print(x > y or y < z)
# ```

# %%
x = 5
y = 10
z = 15
print(x < y and y < z)
print(x > y or y < z)
# Out:
# True
# True

# %% [markdown]
# *Problem 15 (IMPORTANT)*
#
# Write a program that:
#
# * takes a number from user
# * prints `True` if the number is **even and greater than 10**
# * else prints `False`

# %%
num = int(input("Enter your number:"))

print(num%2==0 and num>10)
# Out:
# False
